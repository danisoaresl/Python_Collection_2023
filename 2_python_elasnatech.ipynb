# %% [markdown]
# <a href="https://colab.research.google.com/github/danisoaresl/exercicios_python_elasnatech/blob/danisoaresl/2_python_elasnatech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Qual é o seu nome?")
print(name)
